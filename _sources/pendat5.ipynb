# %% [markdown]
# # Algoritma K-Means

# %% [markdown]
# ## Penjelasan Singkat:
#
# K-means Clustering adalah algoritma unsupervised learning yang digunakan untuk mengelompokkan data ke dalam beberapa kelompok (cluster) berdasarkan kemiripan karakteristik. K-means bekerja dengan cara membagi data ke dalam K jumlah cluster, di mana setiap data dimasukkan ke dalam cluster yang memiliki centroid (titik pusat) terdekat. Proses ini diulang hingga posisi centroid stabil (tidak berubah banyak lagi).
#
# ## Manfaat Clustering
#
# 1. Segmentasi Data yang Efisien
# K-means sangat berguna untuk membagi data besar menjadi kelompok-kelompok yang bermakna.
#
# 2. Penyederhanaan Data
# Dengan mengelompokkan data ke dalam cluster, kita bisa menganalisis representasi data secara lebih sederhana (hanya melihat centroid dari masing-masing cluster).
#
# 3. Skalabilitas Tinggi
# K-means bekerja cepat dan efisien untuk dataset besar, terutama jika jumlah cluster tidak terlalu banyak.
#
# 4. Penerapan Luas di Dunia Nyata
# Algoritma ini digunakan dalam berbagai bidang.
#
# 5. Mudah Dipahami dan Diimplementasikan
# K-means cukup sederhana dibanding metode clustering lainnya, sehingga cocok untuk pemula maupun pengembangan cepat prototipe.

# %% [markdown]
# ## **Inertia (Sum Square error/SSE)**
#
#
# Dalam konteks algoritma *K-Means Clustering*, *inertia* (Sum Square error/SSE) adalah salah satu metrik evaluasi untuk menilai seberapa baik data dikelompokkan ke dalam klaster serta mengukur jumlah total jarak kuadrat antara setiap titik data dan pusat klaster (centroid) tempat titik tersebut.
#
# Inertia didefinisikan sebagai:
#
# $$
# \text{Inertia} = \sum_{i=1}^{n} \left\| x_i - \mu_{c_i} \right\|^2
# $$
#
# **Penjelasan Notasi**
# - $x_i$: Titik data ke-$i$
# - $\mu_{c_i}$: Centroid dari klaster tempat $x_i$ berada
# - $\left\| x_i - \mu_{c_i} \right\|^2$: Jarak Euclidean kuadrat antara $x_i$ dan centroid-nya
# - $n$: Jumlah total data

# %% [markdown]
# ## **Silhouette Analysis**
#
#
# Silhouette Analysis adalah metrik evaluasi lain yang lebih baik dari inertia dalam banyak kasus untuk mengevaluasi hasil clustering, seperti pada K-Means, karena mempertimbangkan dua hal sekaligus yaitu:
#
# - Kepadatan dalam klaster
#
# - Jarak antar klaster
#
# Silhouette Analysis mengukur seberapa mirip suatu titik data dengan klasternya sendiri dibandingkan dengan klaster terdekat lainnya. Rumusnya adalah:
#
# $$
# s(i) = \frac{b(i) - a(i)}{\max(a(i), b(i))}
# $$
#
# **Penjelasan Notasi**:
# - $a(i)$: Rata-rata jarak dari titik $i$ ke semua titik lain dalam klaster yang sama (cohesion)
# - $b(i)$: Rata-rata jarak dari titik $i$ ke semua titik dalam klaster terdekat yang bukan miliknya (separation)
# - $s(i)$: Skor silhouette untuk titik $i$, dengan nilai antara -1 dan 1
#
# Nilai skor $s(i)$ ditafsirkan sebagai berikut:
# - Jika $s(i) \approx 1$, maka titik berada jauh dari klaster lain dan cocok dengan klasternya
# - Jika $s(i) \approx 0$, maka titik berada di antara dua klaster
# - Jika $s(i) \approx -1$, maka titik bisa jadi salah masuk klaster
#
# Untuk mengevaluasi seluruh hasil clustering, digunakan rata-rata dari semua $s(i)$:
#
# $$
# S = \frac{1}{n} \sum_{i=1}^{n} s(i)
# $$
#
# - $n$: Jumlah total data
# - $S$: Silhouette score rata-rata seluruh data

# %% [markdown]
# ## **Implementasi dengan menggunakan data Iris**

# %%
# %pip install pymysql
# %pip install psycopg2
# Out:
# Requirement already satisfied: pymysql in /usr/local/python/3.12.1/lib/python3.12/site-packages (1.1.1)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: psycopg2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (2.9.10)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## **Library yang digunakan**

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import adjusted_rand_score
from sklearn.metrics import silhouette_score
import psycopg2
import pymysql
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## **Pengumpulan Data**

# %%
def get_pg_data():
    conn = psycopg2.connect(
        host="pg-23566fa8-poostgree.d.aivencloud.com",
        user="avnadmin",
        password="AVNS_PQHHNe5BmPwoXLKHHad",
        database="defaultdb",
        port=19790
    )
    cursor = conn.cursor()
    cursor.execute("SELECT * FROM rossi.postgree")
    data = cursor.fetchall()
    columns = [desc[0] for desc in cursor.description]
    cursor.close()
    conn.close()
    return pd.DataFrame(data, columns=columns)

def get_mysql_data():
    conn = pymysql.connect(
        host="mysql-761e1af-mysqlmysql.d.aivencloud.com",
        user="avnadmin",
        password="AVNS_b3-R_nwIM0G13-jogyl",
        database="defaultdb",
        port=22667
    )
    cursor = conn.cursor()
    cursor.execute("SELECT * FROM flowers")
    data = cursor.fetchall()
    columns = [desc[0] for desc in cursor.description]
    cursor.close()
    conn.close()
    return pd.DataFrame(data, columns=columns)

# Ambil data dari kedua database
df_postgresql = get_pg_data()
df_mysql = get_mysql_data()

# Gabungkan berdasarkan kolom 'id' dan 'Class'
df_postgresql = df_postgresql.rename(columns={'Class': 'class'})
df_merged = pd.merge(df_mysql, df_postgresql, on=["id", "class"], how="inner")

# Cetak semua data hasil gabungan tanpa indeks
print(df_merged.to_string(index=False))
# Out:
#  id           class  petal length  petal width  sepal length  sepal width
#   1     Iris-setosa          86.4         70.0          20.1         30.5
#   2     Iris-setosa           1.4          0.2           4.9          3.0
#   3     Iris-setosa           1.3          0.2           4.7          3.2
#   4     Iris-setosa           1.5          0.2           4.6          3.1
#   5     Iris-setosa           1.4          0.2           5.0          3.6
#   6     Iris-setosa           1.7          0.4           5.4          3.9
#   7     Iris-setosa           1.4          0.3           4.6          3.4
#   8     Iris-setosa           1.5          0.2           5.0          3.4
#   9     Iris-setosa           1.4          0.2           4.4          2.9
#  10     Iris-setosa           1.5          0.1           4.9          3.1
#  11     Iris-setosa           1.5          0.2           5.4          3.7
#  12     Iris-setosa           1.6          0.2           4.8          3.4
#  13     Iris-setosa           1.4          0.1           4.8          3.0
#  14     Iris-setosa           1.1          0.1           4.3          3.0
#  15     Iris-setosa           1.2          0.2           5.8          4.0
#  16     Iris-setosa           1.5          0.4           5.7          4.4
#  17     Iris-setosa           1.3          0.4           5.4          3.9
#  18     Iris-setosa           1.4          0.3           5.1          3.5
#  19     Iris-setosa           1.7          0.3           5.7          3.8
#  20     Iris-setosa           1.5          0.3           5.1          3.8
#  21     Iris-setosa           1.7          0.2           5.4          3.4
#  22     Iris-setosa           1.5          0.4           5.1          3.7
#  23     Iris-setosa           1.0          0.2           4.6          3.6
#  24     Iris-setosa           1.7          0.5           5.1          3.3
#  25     Iris-setosa           1.9          0.2           4.8          3.4
#  26     Iris-setosa           1.6          0.2           5.0          3.0
#  27     Iris-setosa           1.6          0.4           5.0          3.4
#  28     Iris-setosa           1.5          0.2           5.2          3.5
#  29     Iris-setosa           1.4          0.2           5.2          3.4
#  30     Iris-setosa           1.6          0.2           4.7          3.2
#  31     Iris-setosa           1.6          0.2           4.8          3.1
#  32     Iris-setosa           1.5          0.4           5.4          3.4
#  33     Iris-setosa           1.5          0.1           5.2          4.1
#  34     Iris-setosa           1.4          0.2           5.5          4.2
#  35     Iris-setosa           1.5          0.1           4.9          3.1
#  36     Iris-setosa           1.2          0.2           5.0          3.2
#  37     Iris-setosa           1.3          0.2           5.5          3.5
#  38     Iris-setosa           1.5          0.1           4.9          3.1
#  39     Iris-setosa           1.3          0.2           4.4          3.0
#  40     Iris-setosa           1.5          0.2           5.1          3.4
#  41     Iris-setosa           1.3          0.3           5.0          3.5
#  42     Iris-setosa           1.3          0.3           4.5          2.3
#  43     Iris-setosa           1.3          0.2           4.4          3.2
#  44     Iris-setosa           1.6          0.6           5.0          3.5
#  45     Iris-setosa           1.9          0.4           5.1          3.8
#  46     Iris-setosa           1.4          0.3           4.8          3.0
#  47     Iris-setosa           1.6          0.2           5.1          3.8
#  48     Iris-setosa           1.4          0.2           4.6          3.2
#  49     Iris-setosa           1.5          0.2           5.3          3.7
#  50     Iris-setosa           1.4          0.2           5.0          3.3
#  51 Iris-versicolor           4.7          1.4           7.0          3.2
#  52 Iris-versicolor           4.5          1.5           6.4          3.2
#  53 Iris-versicolor           4.9          1.5           6.9          3.1
#  54 Iris-versicolor           4.0          1.3           5.5          2.3
#  55 Iris-versicolor           4.6          1.5           6.5          2.8
#  56 Iris-versicolor           4.5          1.3           5.7          2.8
#  57 Iris-versicolor           4.7          1.6           6.3          3.3
#  58 Iris-versicolor           3.3          1.0           4.9          2.4
#  59 Iris-versicolor           4.6          1.3           6.6          2.9
#  60 Iris-versicolor           3.9          1.4           5.2          2.7
#  61 Iris-versicolor           3.5          1.0           5.0          2.0
#  62 Iris-versicolor           4.2          1.5           5.9          3.0
#  63 Iris-versicolor           4.0          1.0           6.0          2.2
#  64 Iris-versicolor           4.7          1.4           6.1          2.9
#  65 Iris-versicolor           3.6          1.3           5.6          2.9
#  66 Iris-versicolor           4.4          1.4           6.7          3.1
#  67 Iris-versicolor           4.5          1.5           5.6          3.0
#  68 Iris-versicolor           4.1          1.0           5.8          2.7
#  69 Iris-versicolor           4.5          1.5           6.2          2.2
#  70 Iris-versicolor           3.9          1.1           5.6          2.5
#  71 Iris-versicolor           4.8          1.8           5.9          3.2
#  72 Iris-versicolor           4.0          1.3           6.1          2.8
#  73 Iris-versicolor           4.9          1.5           6.3          2.5
#  74 Iris-versicolor           4.7          1.2           6.1          2.8
#  75 Iris-versicolor           4.3          1.3           6.4          2.9
#  76 Iris-versicolor           4.4          1.4           6.6          3.0
#  77 Iris-versicolor           4.8          1.4           6.8          2.8
#  78 Iris-versicolor           5.0          1.7           6.7          3.0
#  79 Iris-versicolor           4.5          1.5           6.0          2.9
#  80 Iris-versicolor           3.5          1.0           5.7          2.6
#  81 Iris-versicolor           3.8          1.1           5.5          2.4
#  82 Iris-versicolor           3.7          1.0           5.5          2.4
#  83 Iris-versicolor           3.9          1.2           5.8          2.7
#  84 Iris-versicolor           5.1          1.6           6.0          2.7
#  85 Iris-versicolor           4.5          1.5           5.4          3.0
#  86 Iris-versicolor           4.5          1.6           6.0          3.4
#  87 Iris-versicolor           4.7          1.5           6.7          3.1
#  88 Iris-versicolor           4.4          1.3           6.3          2.3
#  89 Iris-versicolor           4.1          1.3           5.6          3.0
#  90 Iris-versicolor           4.0          1.3           5.5          2.5
#  91 Iris-versicolor           4.4          1.2           5.5          2.6
#  92 Iris-versicolor           4.6          1.4           6.1          3.0
#  93 Iris-versicolor           4.0          1.2           5.8          2.6
#  94 Iris-versicolor           3.3          1.0           5.0          2.3
#  95 Iris-versicolor           4.2          1.3           5.6          2.7
#  96 Iris-versicolor           4.2          1.2           5.7          3.0
#  97 Iris-versicolor           4.2          1.3           5.7          2.9
#  98 Iris-versicolor           4.3          1.3           6.2          2.9
#  99 Iris-versicolor           3.0          1.1           5.1          2.5
# 100 Iris-versicolor           4.1          1.3           5.7          2.8
# 101  Iris-virginica           6.0          2.5           6.3          3.3
# 102  Iris-virginica           5.1          1.9           5.8          2.7
# 103  Iris-virginica           5.9          2.1           7.1          3.0
# 104  Iris-virginica           5.6          1.8           6.3          2.9
# 105  Iris-virginica           5.8          2.2           6.5          3.0
# 106  Iris-virginica           6.6          2.1           7.6          3.0
# 107  Iris-virginica           4.5          1.7           4.9          2.5
# 108  Iris-virginica           6.3          1.8           7.3          2.9
# 109  Iris-virginica           5.8          1.8           6.7          2.5
# 110  Iris-virginica           6.1          2.5           7.2          3.6
# 111  Iris-virginica           5.1          2.0           6.5          3.2
# 112  Iris-virginica           5.3          1.9           6.4          2.7
# 113  Iris-virginica           5.5          2.1           6.8          3.0
# 114  Iris-virginica           5.0          2.0           5.7          2.5
# 115  Iris-virginica           5.1          2.4           5.8          2.8
# 116  Iris-virginica           5.3          2.3           6.4          3.2
# 117  Iris-virginica           5.5          1.8           6.5          3.0
# 118  Iris-virginica           6.7          2.2           7.7          3.8
# 119  Iris-virginica           6.9          2.3           7.7          2.6
# 120  Iris-virginica           5.0          1.5           6.0          2.2
# 121  Iris-virginica           5.7          2.3           6.9          3.2
# 122  Iris-virginica           4.9          2.0           5.6          2.8
# 123  Iris-virginica           6.7          2.0           7.7          2.8
# 124  Iris-virginica           4.9          1.8           6.3          2.7
# 125  Iris-virginica           5.7          2.1           6.7          3.3
# 126  Iris-virginica           6.0          1.8           7.2          3.2
# 127  Iris-virginica           4.8          1.8           6.2          2.8
# 128  Iris-virginica           4.9          1.8           6.1          3.0
# 129  Iris-virginica           5.6          2.1           6.4          2.8
# 130  Iris-virginica           5.8          1.6           7.2          3.0
# 131  Iris-virginica           6.1          1.9           7.4          2.8
# 132  Iris-virginica           6.4          2.0           7.9          3.8
# 133  Iris-virginica           5.6          2.2           6.4          2.8
# 134  Iris-virginica           5.1          1.5           6.3          2.8
# 135  Iris-virginica           5.6          1.4           6.1          2.6
# 136  Iris-virginica           6.1          2.3           7.7          3.0
# 137  Iris-virginica           5.6          2.4           6.3          3.4
# 138  Iris-virginica           5.5          1.8           6.4          3.1
# 139  Iris-virginica           4.8          1.8           6.0          3.0
# 140  Iris-virginica           5.4          2.1           6.9          3.1
# 141  Iris-virginica           5.6          2.4           6.7          3.1
# 142  Iris-virginica           5.1          2.3           6.9          3.1
# 143  Iris-virginica           5.1          1.9           5.8          2.7
# 144  Iris-virginica           5.9          2.3           6.8          3.2
# 145  Iris-virginica           5.7          2.5           6.7          3.3
# 146  Iris-virginica           5.2          2.3           6.7          3.0
# 147  Iris-virginica           5.0          1.9           6.3          2.5
# 148  Iris-virginica           5.2          2.0           6.5          3.0
# 149  Iris-virginica           5.4          2.3           6.2          3.4
# 150  Iris-virginica           5.1          1.8           5.9          3.0

# %% [markdown]
# ## **Clustering pada data Iris menggunakan K-Means dengan jumlah cluster 2,3 dan 4**

# %%
# 1. Siapkan fitur (X) dan label (y)
feature_names = ['sepal length', 'sepal width', 'petal length', 'petal width']
X = df_merged[feature_names].values
y = df_merged['class'].astype('category').cat.codes.values  # label dikodekan ke angka

# 2. Standarisasi
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 3. Fungsi clustering
def perform_kmeans(X_scaled, y, k):
    kmeans = KMeans(n_clusters=k, random_state=42)
    labels = kmeans.fit_predict(X_scaled)
    centroids = kmeans.cluster_centers_
    accuracy = adjusted_rand_score(y, labels)

    print(f"\nHasil K-Means dengan {k} Klaster:")
    print(f"Centroids:\n{centroids}")
    print(f"Akurasi (Adjusted Rand Score): {accuracy:.3f}")

    return labels, centroids, accuracy

# 4. Jalankan clustering
for k in [2, 3, 4]:
    perform_kmeans(X_scaled, y, k)
# Out:
# Hasil K-Means dengan 2 Klaster:
# Centroids:
# [[-0.06680904 -0.08044216 -0.07928801 -0.08118589]
#  [ 9.95454726 11.98588211 11.81391278 12.09669818]]
# Akurasi (Adjusted Rand Score): 0.000
#
# Hasil K-Means dengan 3 Klaster:
# Centroids:
# [[ 0.3969107  -0.12798371  0.12328332  0.02361465]
#  [ 9.95454726 11.98588211 11.81391278 12.09669818]
#  [-0.56273155 -0.02959911 -0.29592678 -0.19326426]]
# Akurasi (Adjusted Rand Score): 0.403
#
# Hasil K-Means dengan 4 Klaster:
# Centroids:
# [[ 0.02343901 -0.19004975  0.04625305 -0.01722975]
#  [ 9.95454726 11.98588211 11.81391278 12.09669818]
#  [-0.65948849  0.03141076 -0.37841663 -0.2327625 ]
#  [ 0.73267586 -0.06795556  0.18305349  0.05114777]]
# Akurasi (Adjusted Rand Score): 0.483

# %% [markdown]
# ## **Model Plotting dengan Jumlah Cluster 2, 3 dan 4**

# %%
# 1. Siapkan fitur (X) dan label (y)
feature_names = ['sepal length', 'sepal width', 'petal length', 'petal width']
X = df_merged[feature_names].values
y = df_merged['class'].astype('category').cat.codes.values  # label dikodekan ke angka

# 2. Standarisasi data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 3. Fungsi untuk melakukan K-Means, plotting dan menampilkan centroid
def perform_kmeans_plot(X_scaled, k):
    kmeans = KMeans(n_clusters=k, random_state=42)
    labels = kmeans.fit_predict(X_scaled)

    # Centroid dari masing-masing klaster
    centroids = kmeans.cluster_centers_

    # Plotting data dan centroid
    plt.figure(figsize=(8, 6))

    # Scatter plot untuk 2 fitur pertama (sepal length & sepal width)
    plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=labels, cmap='Set1', marker='o', edgecolors='k', s=100)

    # Plot centroid dengan warna berbeda
    plt.scatter(centroids[:, 0], centroids[:, 1], c='black', marker='X', s=200, label='Centroids')

    plt.title(f"K-Means Clustering with {k} Clusters")
    plt.xlabel(feature_names[0])
    plt.ylabel(feature_names[1])
    plt.legend()
    plt.show()

# 4. Melakukan clustering dengan K=2, K=3, dan K=4 dan plot hasilnya
for k in [2, 3, 4]:
    perform_kmeans_plot(X_scaled, k)

# %% [markdown]
# ## **Menghitung Inertia untuk Jumlah Cluster 2,3 dan 4**

# %%
# 1. Siapkan fitur (X) dan label (y)
feature_names = ['sepal length', 'sepal width', 'petal length', 'petal width']
X = df_merged[feature_names].values
y = df_merged['class'].astype('category').cat.codes.values  # label dikodekan ke angka

# 2. Standarisasi data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 3. Fungsi untuk menghitung inertia secara manual
def calculate_inertia_step_by_step(X_scaled, labels, centroids):
    inertia = 0
    print("Langkah-langkah perhitungan Inertia:")

    for i in range(len(X_scaled)):
        cluster = labels[i]
        distance = np.linalg.norm(X_scaled[i] - centroids[cluster]) ** 2
        inertia += distance
        print(f"Titik data {i+1} (Fitur: {X_scaled[i]}), Klaster: {cluster}, "
              f"Centroid: {centroids[cluster]}, Jarak kuadrat: {distance:.3f}, "
              f"Inertia sementara: {inertia:.3f}")

    return inertia

# 4. Fungsi untuk menjalankan KMeans dan menghitung inertia manual
def perform_kmeans(X_scaled, y, k):
    kmeans = KMeans(n_clusters=k, random_state=42)
    labels = kmeans.fit_predict(X_scaled)
    centroids = kmeans.cluster_centers_

    print(f"\n=== Hasil K-Means dengan {k} Klaster ===")
    print(f"Centroids (fitur hasil standarisasi):\n{centroids}")

    # Hitung inertia manual
    manual_inertia = calculate_inertia_step_by_step(X_scaled, labels, centroids)
    print(f"\nTotal Inertia Manual: {manual_inertia:.3f}")

    # Bandingkan dengan inertia dari sklearn
    sklearn_inertia = kmeans.inertia_
    print(f"Inertia dari sklearn: {sklearn_inertia:.3f}")
    print("="*50)

    return labels, centroids, manual_inertia

# 5. Jalankan untuk k=2, 3, dan 4
for k in [2, 3, 4]:
    perform_kmeans(X_scaled, y, k)
# Out:
# === Hasil K-Means dengan 2 Klaster ===
# Centroids (fitur hasil standarisasi):
# [[-0.06680904 -0.08044216 -0.07928801 -0.08118589]
#  [ 9.95454726 11.98588211 11.81391278 12.09669818]]
# Langkah-langkah perhitungan Inertia:
# Titik data 1 (Fitur: [ 9.95454726 11.98588211 11.81391278 12.09669818]), Klaster: 1, Centroid: [ 9.95454726 11.98588211 11.81391278 12.09669818], Jarak kuadrat: 0.000, Inertia sementara: 0.000
# Titik data 2 (Fitur: [-0.73364099 -0.10286424 -0.42107552 -0.25915427]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.594, Inertia sementara: 0.594
# Titik data 3 (Fitur: [-0.87427505 -0.01494609 -0.43546962 -0.25915427]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.815, Inertia sementara: 1.408
# Titik data 4 (Fitur: [-0.94459208 -0.05890516 -0.40668141 -0.25915427]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.910, Inertia sementara: 2.318
# Titik data 5 (Fitur: [-0.66332396  0.16089022 -0.42107552 -0.25915427]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.563, Inertia sementara: 2.881
# Titik data 6 (Fitur: [-0.38205585  0.29276746 -0.37789321 -0.22375068]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.348, Inertia sementara: 3.229
# Titik data 7 (Fitur: [-0.94459208  0.07297207 -0.42107552 -0.24145247]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.937, Inertia sementara: 4.166
# Titik data 8 (Fitur: [-0.66332396  0.07297207 -0.40668141 -0.25915427]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.518, Inertia sementara: 4.684
# Titik data 9 (Fitur: [-1.08522613 -0.14682332 -0.42107552 -0.25915427]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 1.190, Inertia sementara: 5.874
# Titik data 10 (Fitur: [-0.73364099 -0.05890516 -0.40668141 -0.27685606]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.591, Inertia sementara: 6.464
# Titik data 11 (Fitur: [-0.38205585  0.2048493  -0.40668141 -0.25915427]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.320, Inertia sementara: 6.784
# Titik data 12 (Fitur: [-0.80395802  0.07297207 -0.39228731 -0.25915427]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.697, Inertia sementara: 7.481
# Titik data 13 (Fitur: [-0.80395802 -0.10286424 -0.42107552 -0.27685606]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.699, Inertia sementara: 8.180
# Titik data 14 (Fitur: [-1.15554316 -0.10286424 -0.46425783 -0.27685606]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 1.372, Inertia sementara: 9.552
# Titik data 15 (Fitur: [-0.10078774  0.33672653 -0.44986373 -0.25915427]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.344, Inertia sementara: 9.896
# Titik data 16 (Fitur: [-0.17110477  0.51256285 -0.40668141 -0.22375068]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.490, Inertia sementara: 10.386
# Titik data 17 (Fitur: [-0.38205585  0.29276746 -0.43546962 -0.22375068]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.386, Inertia sementara: 10.772
# Titik data 18 (Fitur: [-0.59300694  0.11693115 -0.42107552 -0.24145247]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.458, Inertia sementara: 11.230
# Titik data 19 (Fitur: [-0.17110477  0.24880838 -0.37789321 -0.24145247]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.234, Inertia sementara: 11.465
# Titik data 20 (Fitur: [-0.59300694  0.24880838 -0.40668141 -0.24145247]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.518, Inertia sementara: 11.983
# Titik data 21 (Fitur: [-0.38205585  0.07297207 -0.37789321 -0.25915427]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.244, Inertia sementara: 12.226
# Titik data 22 (Fitur: [-0.59300694  0.2048493  -0.40668141 -0.22375068]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.486, Inertia sementara: 12.712
# Titik data 23 (Fitur: [-0.94459208  0.16089022 -0.47865193 -0.25915427]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 1.020, Inertia sementara: 13.732
# Titik data 24 (Fitur: [-0.59300694  0.02901299 -0.37789321 -0.20604889]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.394, Inertia sementara: 14.126
# Titik data 25 (Fitur: [-0.80395802  0.07297207 -0.349105   -0.25915427]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.671, Inertia sementara: 14.797
# Titik data 26 (Fitur: [-0.66332396 -0.10286424 -0.39228731 -0.25915427]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.486, Inertia sementara: 15.283
# Titik data 27 (Fitur: [-0.66332396  0.07297207 -0.39228731 -0.22375068]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.498, Inertia sementara: 15.781
# Titik data 28 (Fitur: [-0.52268991  0.11693115 -0.40668141 -0.25915427]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.386, Inertia sementara: 16.166
# Titik data 29 (Fitur: [-0.52268991  0.07297207 -0.42107552 -0.25915427]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.380, Inertia sementara: 16.546
# Titik data 30 (Fitur: [-0.87427505 -0.01494609 -0.39228731 -0.25915427]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.786, Inertia sementara: 17.332
# Titik data 31 (Fitur: [-0.80395802 -0.05890516 -0.39228731 -0.25915427]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.673, Inertia sementara: 18.006
# Titik data 32 (Fitur: [-0.38205585  0.07297207 -0.40668141 -0.22375068]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.250, Inertia sementara: 18.256
# Titik data 33 (Fitur: [-0.52268991  0.38068561 -0.40668141 -0.27685606]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.566, Inertia sementara: 18.822
# Titik data 34 (Fitur: [-0.31173882  0.42464469 -0.42107552 -0.25915427]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.464, Inertia sementara: 19.286
# Titik data 35 (Fitur: [-0.73364099 -0.05890516 -0.40668141 -0.27685606]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.591, Inertia sementara: 19.876
# Titik data 36 (Fitur: [-0.66332396 -0.01494609 -0.44986373 -0.25915427]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.529, Inertia sementara: 20.405
# Titik data 37 (Fitur: [-0.31173882  0.11693115 -0.43546962 -0.25915427]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.257, Inertia sementara: 20.663
# Titik data 38 (Fitur: [-0.73364099 -0.05890516 -0.40668141 -0.27685606]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.591, Inertia sementara: 21.254
# Titik data 39 (Fitur: [-1.08522613 -0.10286424 -0.43546962 -0.25915427]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 1.196, Inertia sementara: 22.450
# Titik data 40 (Fitur: [-0.59300694  0.07297207 -0.40668141 -0.25915427]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.439, Inertia sementara: 22.889
# Titik data 41 (Fitur: [-0.66332396  0.11693115 -0.43546962 -0.24145247]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.547, Inertia sementara: 23.436
# Titik data 42 (Fitur: [-1.0149091  -0.41057779 -0.43546962 -0.24145247]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 1.160, Inertia sementara: 24.597
# Titik data 43 (Fitur: [-1.08522613 -0.01494609 -0.43546962 -0.25915427]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 1.200, Inertia sementara: 25.797
# Titik data 44 (Fitur: [-0.66332396  0.11693115 -0.39228731 -0.18834709]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.504, Inertia sementara: 26.301
# Titik data 45 (Fitur: [-0.59300694  0.24880838 -0.349105   -0.22375068]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.478, Inertia sementara: 26.779
# Titik data 46 (Fitur: [-0.80395802 -0.10286424 -0.42107552 -0.24145247]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.686, Inertia sementara: 27.466
# Titik data 47 (Fitur: [-0.59300694  0.24880838 -0.39228731 -0.25915427]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.515, Inertia sementara: 27.981
# Titik data 48 (Fitur: [-0.94459208 -0.01494609 -0.42107552 -0.25915427]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.923, Inertia sementara: 28.904
# Titik data 49 (Fitur: [-0.45237288  0.2048493  -0.40668141 -0.25915427]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.369, Inertia sementara: 29.273
# Titik data 50 (Fitur: [-0.66332396  0.02901299 -0.42107552 -0.25915427]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.516, Inertia sementara: 29.789
# Titik data 51 (Fitur: [ 0.7430166  -0.01494609  0.05392991 -0.04673274]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.679, Inertia sementara: 30.468
# Titik data 52 (Fitur: [ 0.32111443 -0.01494609  0.0251417  -0.02903094]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.168, Inertia sementara: 30.637
# Titik data 53 (Fitur: [ 0.67269957 -0.05890516  0.08271812 -0.02903094]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.576, Inertia sementara: 31.213
# Titik data 54 (Fitur: [-0.31173882 -0.41057779 -0.04682882 -0.06443453]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.170, Inertia sementara: 31.383
# Titik data 55 (Fitur: [ 0.39143146 -0.1907824   0.03953581 -0.02903094]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.239, Inertia sementara: 31.622
# Titik data 56 (Fitur: [-0.17110477 -0.1907824   0.0251417  -0.06443453]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.034, Inertia sementara: 31.657
# Titik data 57 (Fitur: [ 0.2507974   0.02901299  0.05392991 -0.01132915]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.135, Inertia sementara: 31.792
# Titik data 58 (Fitur: [-0.73364099 -0.36661871 -0.14758755 -0.11753991]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.533, Inertia sementara: 32.325
# Titik data 59 (Fitur: [ 0.46174848 -0.14682332  0.03953581 -0.06443453]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.298, Inertia sementara: 32.623
# Titik data 60 (Fitur: [-0.52268991 -0.23474147 -0.06122292 -0.04673274]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.233, Inertia sementara: 32.856
# Titik data 61 (Fitur: [-0.66332396 -0.54245502 -0.11879934 -0.11753991]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.572, Inertia sementara: 33.428
# Titik data 62 (Fitur: [-0.03047071 -0.10286424 -0.01804061 -0.02903094]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.008, Inertia sementara: 33.436
# Titik data 63 (Fitur: [ 0.03984632 -0.45453686 -0.04682882 -0.11753991]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.154, Inertia sementara: 33.590
# Titik data 64 (Fitur: [ 0.11016334 -0.14682332  0.05392991 -0.04673274]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.055, Inertia sementara: 33.645
# Titik data 65 (Fitur: [-0.2414218  -0.14682332 -0.10440523 -0.06443453]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.036, Inertia sementara: 33.681
# Titik data 66 (Fitur: [ 0.53206551 -0.05890516  0.0107476  -0.04673274]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.368, Inertia sementara: 34.049
# Titik data 67 (Fitur: [-0.2414218  -0.10286424  0.0251417  -0.02903094]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.045, Inertia sementara: 34.094
# Titik data 68 (Fitur: [-0.10078774 -0.23474147 -0.03243471 -0.11753991]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.028, Inertia sementara: 34.122
# Titik data 69 (Fitur: [ 0.18048037 -0.45453686  0.0251417  -0.02903094]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.215, Inertia sementara: 34.337
# Titik data 70 (Fitur: [-0.2414218  -0.32265963 -0.06122292 -0.09983812]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.090, Inertia sementara: 34.427
# Titik data 71 (Fitur: [-0.03047071 -0.01494609  0.06832401  0.02407444]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.038, Inertia sementara: 34.465
# Titik data 72 (Fitur: [ 0.11016334 -0.1907824  -0.04682882 -0.06443453]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.045, Inertia sementara: 34.510
# Titik data 73 (Fitur: [ 0.2507974  -0.32265963  0.08271812 -0.02903094]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.189, Inertia sementara: 34.698
# Titik data 74 (Fitur: [ 0.11016334 -0.1907824   0.05392991 -0.08213633]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.061, Inertia sementara: 34.760
# Titik data 75 (Fitur: [ 0.32111443 -0.14682332 -0.00364651 -0.06443453]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.161, Inertia sementara: 34.921
# Titik data 76 (Fitur: [ 0.46174848 -0.10286424  0.0107476  -0.04673274]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.289, Inertia sementara: 35.210
# Titik data 77 (Fitur: [ 0.60238254 -0.1907824   0.06832401 -0.04673274]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.483, Inertia sementara: 35.693
# Titik data 78 (Fitur: [ 0.53206551 -0.10286424  0.09711222  0.00637265]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.398, Inertia sementara: 36.091
# Titik data 79 (Fitur: [ 0.03984632 -0.14682332  0.0251417  -0.02903094]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.029, Inertia sementara: 36.120
# Titik data 80 (Fitur: [-0.17110477 -0.27870055 -0.11879934 -0.11753991]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.053, Inertia sementara: 36.173
# Titik data 81 (Fitur: [-0.31173882 -0.36661871 -0.07561703 -0.09983812]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.142, Inertia sementara: 36.315
# Titik data 82 (Fitur: [-0.31173882 -0.36661871 -0.09001113 -0.11753991]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.143, Inertia sementara: 36.459
# Titik data 83 (Fitur: [-0.10078774 -0.23474147 -0.06122292 -0.08213633]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.025, Inertia sementara: 36.484
# Titik data 84 (Fitur: [ 0.03984632 -0.23474147  0.11150632 -0.01132915]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.076, Inertia sementara: 36.560
# Titik data 85 (Fitur: [-0.38205585 -0.10286424  0.0251417  -0.02903094]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.114, Inertia sementara: 36.674
# Titik data 86 (Fitur: [ 0.03984632  0.07297207  0.0251417  -0.01132915]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.051, Inertia sementara: 36.725
# Titik data 87 (Fitur: [ 0.53206551 -0.05890516  0.05392991 -0.02903094]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.380, Inertia sementara: 37.104
# Titik data 88 (Fitur: [ 0.2507974  -0.41057779  0.0107476  -0.06443453]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.218, Inertia sementara: 37.322
# Titik data 89 (Fitur: [-0.2414218  -0.10286424 -0.03243471 -0.06443453]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.033, Inertia sementara: 37.356
# Titik data 90 (Fitur: [-0.31173882 -0.32265963 -0.04682882 -0.06443453]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.120, Inertia sementara: 37.476
# Titik data 91 (Fitur: [-0.31173882 -0.27870055  0.0107476  -0.08213633]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.107, Inertia sementara: 37.583
# Titik data 92 (Fitur: [ 0.11016334 -0.10286424  0.03953581 -0.04673274]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.047, Inertia sementara: 37.630
# Titik data 93 (Fitur: [-0.10078774 -0.27870055 -0.04682882 -0.08213633]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.042, Inertia sementara: 37.672
# Titik data 94 (Fitur: [-0.66332396 -0.41057779 -0.14758755 -0.11753991]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.471, Inertia sementara: 38.143
# Titik data 95 (Fitur: [-0.2414218  -0.23474147 -0.01804061 -0.06443453]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.058, Inertia sementara: 38.201
# Titik data 96 (Fitur: [-0.17110477 -0.10286424 -0.01804061 -0.08213633]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.015, Inertia sementara: 38.216
# Titik data 97 (Fitur: [-0.17110477 -0.14682332 -0.01804061 -0.06443453]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.019, Inertia sementara: 38.236
# Titik data 98 (Fitur: [ 0.18048037 -0.14682332 -0.00364651 -0.06443453]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.072, Inertia sementara: 38.307
# Titik data 99 (Fitur: [-0.59300694 -0.32265963 -0.19076986 -0.09983812]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.348, Inertia sementara: 38.655
# Titik data 100 (Fitur: [-0.17110477 -0.1907824  -0.03243471 -0.06443453]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.026, Inertia sementara: 38.681
# Titik data 101 (Fitur: [0.2507974  0.02901299 0.24105326 0.147987  ]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.268, Inertia sementara: 38.949
# Titik data 102 (Fitur: [-0.10078774 -0.23474147  0.11150632  0.04177623]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.076, Inertia sementara: 39.025
# Titik data 103 (Fitur: [ 0.81333362 -0.10286424  0.22665916  0.07717982]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.894, Inertia sementara: 39.919
# Titik data 104 (Fitur: [ 0.2507974  -0.14682332  0.18347684  0.02407444]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.185, Inertia sementara: 40.105
# Titik data 105 (Fitur: [ 0.39143146 -0.10286424  0.21226505  0.09488162]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.326, Inertia sementara: 40.431
# Titik data 106 (Fitur: [ 1.16491876 -0.10286424  0.32741788  0.07717982]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 1.708, Inertia sementara: 42.139
# Titik data 107 (Fitur: [-0.73364099 -0.32265963  0.0251417   0.00637265]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.522, Inertia sementara: 42.661
# Titik data 108 (Fitur: [ 0.95396768 -0.14682332  0.28423557  0.02407444]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 1.190, Inertia sementara: 43.851
# Titik data 109 (Fitur: [ 0.53206551 -0.32265963  0.21226505  0.02407444]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.513, Inertia sementara: 44.364
# Titik data 110 (Fitur: [0.88365065 0.16089022 0.25544736 0.147987  ]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 1.126, Inertia sementara: 45.490
# Titik data 111 (Fitur: [ 0.39143146 -0.01494609  0.11150632  0.05947803]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.270, Inertia sementara: 45.761
# Titik data 112 (Fitur: [ 0.32111443 -0.23474147  0.14029453  0.04177623]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.238, Inertia sementara: 45.999
# Titik data 113 (Fitur: [ 0.60238254 -0.10286424  0.16908274  0.07717982]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.535, Inertia sementara: 46.534
# Titik data 114 (Fitur: [-0.17110477 -0.32265963  0.09711222  0.05947803]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.120, Inertia sementara: 46.654
# Titik data 115 (Fitur: [-0.10078774 -0.1907824   0.11150632  0.13028521]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.094, Inertia sementara: 46.749
# Titik data 116 (Fitur: [ 0.32111443 -0.01494609  0.14029453  0.11258341]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.241, Inertia sementara: 46.989
# Titik data 117 (Fitur: [ 0.39143146 -0.10286424  0.16908274  0.02407444]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.283, Inertia sementara: 47.272
# Titik data 118 (Fitur: [1.23523579 0.24880838 0.34181199 0.09488162]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 2.012, Inertia sementara: 49.284
# Titik data 119 (Fitur: [ 1.23523579 -0.27870055  0.37060019  0.11258341]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 1.975, Inertia sementara: 51.259
# Titik data 120 (Fitur: [ 0.03984632 -0.45453686  0.09711222 -0.02903094]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.185, Inertia sementara: 51.444
# Titik data 121 (Fitur: [ 0.67269957 -0.01494609  0.19787095  0.11258341]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.666, Inertia sementara: 52.110
# Titik data 122 (Fitur: [-0.2414218  -0.1907824   0.08271812  0.05947803]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.089, Inertia sementara: 52.198
# Titik data 123 (Fitur: [ 1.23523579 -0.1907824   0.34181199  0.05947803]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 1.905, Inertia sementara: 54.103
# Titik data 124 (Fitur: [ 0.2507974  -0.23474147  0.08271812  0.02407444]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.162, Inertia sementara: 54.265
# Titik data 125 (Fitur: [0.53206551 0.02901299 0.19787095 0.07717982]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.473, Inertia sementara: 54.737
# Titik data 126 (Fitur: [ 0.88365065 -0.01494609  0.24105326  0.02407444]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 1.021, Inertia sementara: 55.759
# Titik data 127 (Fitur: [ 0.18048037 -0.1907824   0.06832401  0.02407444]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.106, Inertia sementara: 55.865
# Titik data 128 (Fitur: [ 0.11016334 -0.10286424  0.08271812  0.02407444]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.069, Inertia sementara: 55.934
# Titik data 129 (Fitur: [ 0.32111443 -0.1907824   0.18347684  0.07717982]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.257, Inertia sementara: 56.191
# Titik data 130 (Fitur: [ 0.88365065 -0.10286424  0.21226505 -0.01132915]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.994, Inertia sementara: 57.185
# Titik data 131 (Fitur: [ 1.02428471 -0.1907824   0.25544736  0.04177623]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 1.330, Inertia sementara: 58.515
# Titik data 132 (Fitur: [1.37586985 0.24880838 0.29862968 0.05947803]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 2.352, Inertia sementara: 60.867
# Titik data 133 (Fitur: [ 0.32111443 -0.1907824   0.18347684  0.09488162]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.263, Inertia sementara: 61.130
# Titik data 134 (Fitur: [ 0.2507974  -0.1907824   0.11150632 -0.02903094]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.152, Inertia sementara: 61.282
# Titik data 135 (Fitur: [ 0.11016334 -0.27870055  0.18347684 -0.04673274]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.141, Inertia sementara: 61.423
# Titik data 136 (Fitur: [ 1.23523579 -0.10286424  0.25544736  0.11258341]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 1.845, Inertia sementara: 63.268
# Titik data 137 (Fitur: [0.2507974  0.07297207 0.18347684 0.13028521]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.238, Inertia sementara: 63.506
# Titik data 138 (Fitur: [ 0.32111443 -0.05890516  0.16908274  0.02407444]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.224, Inertia sementara: 63.730
# Titik data 139 (Fitur: [ 0.03984632 -0.10286424  0.06832401  0.02407444]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.045, Inertia sementara: 63.775
# Titik data 140 (Fitur: [ 0.67269957 -0.05890516  0.15468864  0.07717982]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.627, Inertia sementara: 64.402
# Titik data 141 (Fitur: [ 0.53206551 -0.05890516  0.18347684  0.13028521]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.473, Inertia sementara: 64.875
# Titik data 142 (Fitur: [ 0.67269957 -0.05890516  0.11150632  0.11258341]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.621, Inertia sementara: 65.496
# Titik data 143 (Fitur: [-0.10078774 -0.23474147  0.11150632  0.04177623]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.076, Inertia sementara: 65.573
# Titik data 144 (Fitur: [ 0.60238254 -0.01494609  0.22665916  0.11258341]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.583, Inertia sementara: 66.156
# Titik data 145 (Fitur: [0.53206551 0.02901299 0.19787095 0.147987  ]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.500, Inertia sementara: 66.656
# Titik data 146 (Fitur: [ 0.53206551 -0.10286424  0.12590043  0.11258341]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.439, Inertia sementara: 67.095
# Titik data 147 (Fitur: [ 0.2507974  -0.32265963  0.09711222  0.04177623]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.206, Inertia sementara: 67.300
# Titik data 148 (Fitur: [ 0.39143146 -0.10286424  0.12590043  0.05947803]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.272, Inertia sementara: 67.573
# Titik data 149 (Fitur: [0.18048037 0.07297207 0.15468864 0.11258341]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.177, Inertia sementara: 67.750
# Titik data 150 (Fitur: [-0.03047071 -0.10286424  0.11150632  0.02407444]), Klaster: 0, Centroid: [-0.06680904 -0.08044216 -0.07928801 -0.08118589], Jarak kuadrat: 0.049, Inertia sementara: 67.799
#
# Total Inertia Manual: 67.799
# Inertia dari sklearn: 67.799
# ==================================================
#
# === Hasil K-Means dengan 3 Klaster ===
# Centroids (fitur hasil standarisasi):
# [[ 0.3969107  -0.12798371  0.12328332  0.02361465]
#  [ 9.95454726 11.98588211 11.81391278 12.09669818]
#  [-0.56273155 -0.02959911 -0.29592678 -0.19326426]]
# Langkah-langkah perhitungan Inertia:
# Titik data 1 (Fitur: [ 9.95454726 11.98588211 11.81391278 12.09669818]), Klaster: 1, Centroid: [ 9.95454726 11.98588211 11.81391278 12.09669818], Jarak kuadrat: 0.000, Inertia sementara: 0.000
# Titik data 2 (Fitur: [-0.73364099 -0.10286424 -0.42107552 -0.25915427]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.055, Inertia sementara: 0.055
# Titik data 3 (Fitur: [-0.87427505 -0.01494609 -0.43546962 -0.25915427]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.121, Inertia sementara: 0.176
# Titik data 4 (Fitur: [-0.94459208 -0.05890516 -0.40668141 -0.25915427]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.163, Inertia sementara: 0.339
# Titik data 5 (Fitur: [-0.66332396  0.16089022 -0.42107552 -0.25915427]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.066, Inertia sementara: 0.405
# Titik data 6 (Fitur: [-0.38205585  0.29276746 -0.37789321 -0.22375068]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.144, Inertia sementara: 0.550
# Titik data 7 (Fitur: [-0.94459208  0.07297207 -0.42107552 -0.24145247]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.174, Inertia sementara: 0.724
# Titik data 8 (Fitur: [-0.66332396  0.07297207 -0.40668141 -0.25915427]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.037, Inertia sementara: 0.761
# Titik data 9 (Fitur: [-1.08522613 -0.14682332 -0.42107552 -0.25915427]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.307, Inertia sementara: 1.068
# Titik data 10 (Fitur: [-0.73364099 -0.05890516 -0.40668141 -0.27685606]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.049, Inertia sementara: 1.117
# Titik data 11 (Fitur: [-0.38205585  0.2048493  -0.40668141 -0.25915427]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.104, Inertia sementara: 1.221
# Titik data 12 (Fitur: [-0.80395802  0.07297207 -0.39228731 -0.25915427]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.082, Inertia sementara: 1.304
# Titik data 13 (Fitur: [-0.80395802 -0.10286424 -0.42107552 -0.27685606]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.086, Inertia sementara: 1.390
# Titik data 14 (Fitur: [-1.15554316 -0.10286424 -0.46425783 -0.27685606]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.392, Inertia sementara: 1.782
# Titik data 15 (Fitur: [-0.10078774  0.33672653 -0.44986373 -0.25915427]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.376, Inertia sementara: 2.158
# Titik data 16 (Fitur: [-0.17110477  0.51256285 -0.40668141 -0.22375068]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.461, Inertia sementara: 2.618
# Titik data 17 (Fitur: [-0.38205585  0.29276746 -0.43546962 -0.22375068]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.157, Inertia sementara: 2.775
# Titik data 18 (Fitur: [-0.59300694  0.11693115 -0.42107552 -0.24145247]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.040, Inertia sementara: 2.816
# Titik data 19 (Fitur: [-0.17110477  0.24880838 -0.37789321 -0.24145247]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.240, Inertia sementara: 3.055
# Titik data 20 (Fitur: [-0.59300694  0.24880838 -0.40668141 -0.24145247]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.093, Inertia sementara: 3.149
# Titik data 21 (Fitur: [-0.38205585  0.07297207 -0.37789321 -0.25915427]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.054, Inertia sementara: 3.203
# Titik data 22 (Fitur: [-0.59300694  0.2048493  -0.40668141 -0.22375068]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.069, Inertia sementara: 3.272
# Titik data 23 (Fitur: [-0.94459208  0.16089022 -0.47865193 -0.25915427]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.220, Inertia sementara: 3.492
# Titik data 24 (Fitur: [-0.59300694  0.02901299 -0.37789321 -0.20604889]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.011, Inertia sementara: 3.503
# Titik data 25 (Fitur: [-0.80395802  0.07297207 -0.349105   -0.25915427]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.076, Inertia sementara: 3.579
# Titik data 26 (Fitur: [-0.66332396 -0.10286424 -0.39228731 -0.25915427]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.029, Inertia sementara: 3.608
# Titik data 27 (Fitur: [-0.66332396  0.07297207 -0.39228731 -0.22375068]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.031, Inertia sementara: 3.639
# Titik data 28 (Fitur: [-0.52268991  0.11693115 -0.40668141 -0.25915427]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.040, Inertia sementara: 3.678
# Titik data 29 (Fitur: [-0.52268991  0.07297207 -0.42107552 -0.25915427]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.032, Inertia sementara: 3.711
# Titik data 30 (Fitur: [-0.87427505 -0.01494609 -0.39228731 -0.25915427]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.111, Inertia sementara: 3.821
# Titik data 31 (Fitur: [-0.80395802 -0.05890516 -0.39228731 -0.25915427]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.073, Inertia sementara: 3.894
# Titik data 32 (Fitur: [-0.38205585  0.07297207 -0.40668141 -0.22375068]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.056, Inertia sementara: 3.950
# Titik data 33 (Fitur: [-0.52268991  0.38068561 -0.40668141 -0.27685606]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.189, Inertia sementara: 4.140
# Titik data 34 (Fitur: [-0.31173882  0.42464469 -0.42107552 -0.25915427]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.289, Inertia sementara: 4.429
# Titik data 35 (Fitur: [-0.73364099 -0.05890516 -0.40668141 -0.27685606]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.049, Inertia sementara: 4.478
# Titik data 36 (Fitur: [-0.66332396 -0.01494609 -0.44986373 -0.25915427]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.038, Inertia sementara: 4.517
# Titik data 37 (Fitur: [-0.31173882  0.11693115 -0.43546962 -0.25915427]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.108, Inertia sementara: 4.625
# Titik data 38 (Fitur: [-0.73364099 -0.05890516 -0.40668141 -0.27685606]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.049, Inertia sementara: 4.674
# Titik data 39 (Fitur: [-1.08522613 -0.10286424 -0.43546962 -0.25915427]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.302, Inertia sementara: 4.976
# Titik data 40 (Fitur: [-0.59300694  0.07297207 -0.40668141 -0.25915427]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.028, Inertia sementara: 5.005
# Titik data 41 (Fitur: [-0.66332396  0.11693115 -0.43546962 -0.24145247]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.053, Inertia sementara: 5.058
# Titik data 42 (Fitur: [-1.0149091  -0.41057779 -0.43546962 -0.24145247]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.371, Inertia sementara: 5.429
# Titik data 43 (Fitur: [-1.08522613 -0.01494609 -0.43546962 -0.25915427]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.297, Inertia sementara: 5.726
# Titik data 44 (Fitur: [-0.66332396  0.11693115 -0.39228731 -0.18834709]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.041, Inertia sementara: 5.767
# Titik data 45 (Fitur: [-0.59300694  0.24880838 -0.349105   -0.22375068]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.082, Inertia sementara: 5.849
# Titik data 46 (Fitur: [-0.80395802 -0.10286424 -0.42107552 -0.24145247]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.082, Inertia sementara: 5.931
# Titik data 47 (Fitur: [-0.59300694  0.24880838 -0.39228731 -0.25915427]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.092, Inertia sementara: 6.023
# Titik data 48 (Fitur: [-0.94459208 -0.01494609 -0.42107552 -0.25915427]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.166, Inertia sementara: 6.189
# Titik data 49 (Fitur: [-0.45237288  0.2048493  -0.40668141 -0.25915427]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.084, Inertia sementara: 6.273
# Titik data 50 (Fitur: [-0.66332396  0.02901299 -0.42107552 -0.25915427]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.034, Inertia sementara: 6.306
# Titik data 51 (Fitur: [ 0.7430166  -0.01494609  0.05392991 -0.04673274]), Klaster: 0, Centroid: [ 0.3969107  -0.12798371  0.12328332  0.02361465], Jarak kuadrat: 0.142, Inertia sementara: 6.449
# Titik data 52 (Fitur: [ 0.32111443 -0.01494609  0.0251417  -0.02903094]), Klaster: 0, Centroid: [ 0.3969107  -0.12798371  0.12328332  0.02361465], Jarak kuadrat: 0.031, Inertia sementara: 6.480
# Titik data 53 (Fitur: [ 0.67269957 -0.05890516  0.08271812 -0.02903094]), Klaster: 0, Centroid: [ 0.3969107  -0.12798371  0.12328332  0.02361465], Jarak kuadrat: 0.085, Inertia sementara: 6.565
# Titik data 54 (Fitur: [-0.31173882 -0.41057779 -0.04682882 -0.06443453]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.287, Inertia sementara: 6.852
# Titik data 55 (Fitur: [ 0.39143146 -0.1907824   0.03953581 -0.02903094]), Klaster: 0, Centroid: [ 0.3969107  -0.12798371  0.12328332  0.02361465], Jarak kuadrat: 0.014, Inertia sementara: 6.865
# Titik data 56 (Fitur: [-0.17110477 -0.1907824   0.0251417  -0.06443453]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.299, Inertia sementara: 7.164
# Titik data 57 (Fitur: [ 0.2507974   0.02901299  0.05392991 -0.01132915]), Klaster: 0, Centroid: [ 0.3969107  -0.12798371  0.12328332  0.02361465], Jarak kuadrat: 0.052, Inertia sementara: 7.216
# Titik data 58 (Fitur: [-0.73364099 -0.36661871 -0.14758755 -0.11753991]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.171, Inertia sementara: 7.387
# Titik data 59 (Fitur: [ 0.46174848 -0.14682332  0.03953581 -0.06443453]), Klaster: 0, Centroid: [ 0.3969107  -0.12798371  0.12328332  0.02361465], Jarak kuadrat: 0.019, Inertia sementara: 7.406
# Titik data 60 (Fitur: [-0.52268991 -0.23474147 -0.06122292 -0.04673274]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.120, Inertia sementara: 7.527
# Titik data 61 (Fitur: [-0.66332396 -0.54245502 -0.11879934 -0.11753991]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.310, Inertia sementara: 7.837
# Titik data 62 (Fitur: [-0.03047071 -0.10286424 -0.01804061 -0.02903094]), Klaster: 0, Centroid: [ 0.3969107  -0.12798371  0.12328332  0.02361465], Jarak kuadrat: 0.206, Inertia sementara: 8.043
# Titik data 63 (Fitur: [ 0.03984632 -0.45453686 -0.04682882 -0.11753991]), Klaster: 0, Centroid: [ 0.3969107  -0.12798371  0.12328332  0.02361465], Jarak kuadrat: 0.283, Inertia sementara: 8.326
# Titik data 64 (Fitur: [ 0.11016334 -0.14682332  0.05392991 -0.04673274]), Klaster: 0, Centroid: [ 0.3969107  -0.12798371  0.12328332  0.02361465], Jarak kuadrat: 0.092, Inertia sementara: 8.418
# Titik data 65 (Fitur: [-0.2414218  -0.14682332 -0.10440523 -0.06443453]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.170, Inertia sementara: 8.588
# Titik data 66 (Fitur: [ 0.53206551 -0.05890516  0.0107476  -0.04673274]), Klaster: 0, Centroid: [ 0.3969107  -0.12798371  0.12328332  0.02361465], Jarak kuadrat: 0.041, Inertia sementara: 8.629
# Titik data 67 (Fitur: [-0.2414218  -0.10286424  0.0251417  -0.02903094]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.239, Inertia sementara: 8.868
# Titik data 68 (Fitur: [-0.10078774 -0.23474147 -0.03243471 -0.11753991]), Klaster: 0, Centroid: [ 0.3969107  -0.12798371  0.12328332  0.02361465], Jarak kuadrat: 0.303, Inertia sementara: 9.171
# Titik data 69 (Fitur: [ 0.18048037 -0.45453686  0.0251417  -0.02903094]), Klaster: 0, Centroid: [ 0.3969107  -0.12798371  0.12328332  0.02361465], Jarak kuadrat: 0.166, Inertia sementara: 9.337
# Titik data 70 (Fitur: [-0.2414218  -0.32265963 -0.06122292 -0.09983812]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.253, Inertia sementara: 9.590
# Titik data 71 (Fitur: [-0.03047071 -0.01494609  0.06832401  0.02407444]), Klaster: 0, Centroid: [ 0.3969107  -0.12798371  0.12328332  0.02361465], Jarak kuadrat: 0.198, Inertia sementara: 9.788
# Titik data 72 (Fitur: [ 0.11016334 -0.1907824  -0.04682882 -0.06443453]), Klaster: 0, Centroid: [ 0.3969107  -0.12798371  0.12328332  0.02361465], Jarak kuadrat: 0.123, Inertia sementara: 9.911
# Titik data 73 (Fitur: [ 0.2507974  -0.32265963  0.08271812 -0.02903094]), Klaster: 0, Centroid: [ 0.3969107  -0.12798371  0.12328332  0.02361465], Jarak kuadrat: 0.064, Inertia sementara: 9.975
# Titik data 74 (Fitur: [ 0.11016334 -0.1907824   0.05392991 -0.08213633]), Klaster: 0, Centroid: [ 0.3969107  -0.12798371  0.12328332  0.02361465], Jarak kuadrat: 0.102, Inertia sementara: 10.077
# Titik data 75 (Fitur: [ 0.32111443 -0.14682332 -0.00364651 -0.06443453]), Klaster: 0, Centroid: [ 0.3969107  -0.12798371  0.12328332  0.02361465], Jarak kuadrat: 0.030, Inertia sementara: 10.107
# Titik data 76 (Fitur: [ 0.46174848 -0.10286424  0.0107476  -0.04673274]), Klaster: 0, Centroid: [ 0.3969107  -0.12798371  0.12328332  0.02361465], Jarak kuadrat: 0.022, Inertia sementara: 10.129
# Titik data 77 (Fitur: [ 0.60238254 -0.1907824   0.06832401 -0.04673274]), Klaster: 0, Centroid: [ 0.3969107  -0.12798371  0.12328332  0.02361465], Jarak kuadrat: 0.054, Inertia sementara: 10.184
# Titik data 78 (Fitur: [ 0.53206551 -0.10286424  0.09711222  0.00637265]), Klaster: 0, Centroid: [ 0.3969107  -0.12798371  0.12328332  0.02361465], Jarak kuadrat: 0.020, Inertia sementara: 10.203
# Titik data 79 (Fitur: [ 0.03984632 -0.14682332  0.0251417  -0.02903094]), Klaster: 0, Centroid: [ 0.3969107  -0.12798371  0.12328332  0.02361465], Jarak kuadrat: 0.140, Inertia sementara: 10.344
# Titik data 80 (Fitur: [-0.17110477 -0.27870055 -0.11879934 -0.11753991]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.253, Inertia sementara: 10.596
# Titik data 81 (Fitur: [-0.31173882 -0.36661871 -0.07561703 -0.09983812]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.234, Inertia sementara: 10.830
# Titik data 82 (Fitur: [-0.31173882 -0.36661871 -0.09001113 -0.11753991]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.225, Inertia sementara: 11.055
# Titik data 83 (Fitur: [-0.10078774 -0.23474147 -0.06122292 -0.08213633]), Klaster: 0, Centroid: [ 0.3969107  -0.12798371  0.12328332  0.02361465], Jarak kuadrat: 0.304, Inertia sementara: 11.359
# Titik data 84 (Fitur: [ 0.03984632 -0.23474147  0.11150632 -0.01132915]), Klaster: 0, Centroid: [ 0.3969107  -0.12798371  0.12328332  0.02361465], Jarak kuadrat: 0.140, Inertia sementara: 11.499
# Titik data 85 (Fitur: [-0.38205585 -0.10286424  0.0251417  -0.02903094]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.168, Inertia sementara: 11.667
# Titik data 86 (Fitur: [ 0.03984632  0.07297207  0.0251417  -0.01132915]), Klaster: 0, Centroid: [ 0.3969107  -0.12798371  0.12328332  0.02361465], Jarak kuadrat: 0.179, Inertia sementara: 11.846
# Titik data 87 (Fitur: [ 0.53206551 -0.05890516  0.05392991 -0.02903094]), Klaster: 0, Centroid: [ 0.3969107  -0.12798371  0.12328332  0.02361465], Jarak kuadrat: 0.031, Inertia sementara: 11.877
# Titik data 88 (Fitur: [ 0.2507974  -0.41057779  0.0107476  -0.06443453]), Klaster: 0, Centroid: [ 0.3969107  -0.12798371  0.12328332  0.02361465], Jarak kuadrat: 0.122, Inertia sementara: 11.998
# Titik data 89 (Fitur: [-0.2414218  -0.10286424 -0.03243471 -0.06443453]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.195, Inertia sementara: 12.193
# Titik data 90 (Fitur: [-0.31173882 -0.32265963 -0.04682882 -0.06443453]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.228, Inertia sementara: 12.421
# Titik data 91 (Fitur: [-0.31173882 -0.27870055  0.0107476  -0.08213633]), Klaster: 2, Centroid: [-0.56273155 -0.02959911 -0.29592678 -0.19326426], Jarak kuadrat: 0.231, Inertia sementara: 12.652
# Titik data 92 (Fitur: [ 0.11016334 -0.10286424  0.03953581 -0.04673274]), Klaster: 0, Centroid: [ 0.3969107  -0.12798371  0.12328332  0.02361465], Jarak kuadrat: 0.095, Inertia sementara: 12.747
# Titik data 93 (Fitur: [-0.10078774 -0.27870055 -0.04682882 -0.08213633]), Klaster: 0, Centroid: [ 0.3969107  -0.12798371  0.12328332  0.02361465], Jarak kuadrat: 0.311, Inertia sementara: 13.057
# ...
# Titik data 70 (Fitur: [-0.2414218  -0.32265963 -0.06122292 -0.09983812]), Klaster: 0, Centroid: [ 0.02343901 -0.19004975  0.04625305 -0.01722975], Jarak kuadrat: 0.106, Inertia sementara: 6.814
# Titik data 71 (Fitur: [-0.03047071 -0.01494609  0.06832401  0.02407444]), Klaster: 0, Centroid: [ 0.02343901 -0.19004975  0.04625305 -0.01722975], Jarak kuadrat: 0.036, Inertia sementara: 6.850
# Titik data 72 (Fitur: [ 0.11016334 -0.1907824  -0.04682882 -0.06443453]), Klaster: 0, Centroid: [ 0.02343901 -0.19004975  0.04625305 -0.01722975], Jarak kuadrat: 0.018, Inertia sementara: 6.868
# Titik data 73 (Fitur: [ 0.2507974  -0.32265963  0.08271812 -0.02903094]), Klaster: 0, Centroid: [ 0.02343901 -0.19004975  0.04625305 -0.01722975], Jarak kuadrat: 0.071, Inertia sementara: 6.939
# Titik data 74 (Fitur: [ 0.11016334 -0.1907824   0.05392991 -0.08213633]), Klaster: 0, Centroid: [ 0.02343901 -0.19004975  0.04625305 -0.01722975], Jarak kuadrat: 0.012, Inertia sementara: 6.951
# Titik data 75 (Fitur: [ 0.32111443 -0.14682332 -0.00364651 -0.06443453]), Klaster: 0, Centroid: [ 0.02343901 -0.19004975  0.04625305 -0.01722975], Jarak kuadrat: 0.095, Inertia sementara: 7.046
# Titik data 76 (Fitur: [ 0.46174848 -0.10286424  0.0107476  -0.04673274]), Klaster: 3, Centroid: [ 0.73267586 -0.06795556  0.18305349  0.05114777], Jarak kuadrat: 0.114, Inertia sementara: 7.160
# Titik data 77 (Fitur: [ 0.60238254 -0.1907824   0.06832401 -0.04673274]), Klaster: 3, Centroid: [ 0.73267586 -0.06795556  0.18305349  0.05114777], Jarak kuadrat: 0.055, Inertia sementara: 7.215
# Titik data 78 (Fitur: [ 0.53206551 -0.10286424  0.09711222  0.00637265]), Klaster: 3, Centroid: [ 0.73267586 -0.06795556  0.18305349  0.05114777], Jarak kuadrat: 0.051, Inertia sementara: 7.266
# Titik data 79 (Fitur: [ 0.03984632 -0.14682332  0.0251417  -0.02903094]), Klaster: 0, Centroid: [ 0.02343901 -0.19004975  0.04625305 -0.01722975], Jarak kuadrat: 0.003, Inertia sementara: 7.268
# Titik data 80 (Fitur: [-0.17110477 -0.27870055 -0.11879934 -0.11753991]), Klaster: 0, Centroid: [ 0.02343901 -0.19004975  0.04625305 -0.01722975], Jarak kuadrat: 0.083, Inertia sementara: 7.352
# Titik data 81 (Fitur: [-0.31173882 -0.36661871 -0.07561703 -0.09983812]), Klaster: 0, Centroid: [ 0.02343901 -0.19004975  0.04625305 -0.01722975], Jarak kuadrat: 0.165, Inertia sementara: 7.517
# Titik data 82 (Fitur: [-0.31173882 -0.36661871 -0.09001113 -0.11753991]), Klaster: 0, Centroid: [ 0.02343901 -0.19004975  0.04625305 -0.01722975], Jarak kuadrat: 0.172, Inertia sementara: 7.689
# Titik data 83 (Fitur: [-0.10078774 -0.23474147 -0.06122292 -0.08213633]), Klaster: 0, Centroid: [ 0.02343901 -0.19004975  0.04625305 -0.01722975], Jarak kuadrat: 0.033, Inertia sementara: 7.722
# Titik data 84 (Fitur: [ 0.03984632 -0.23474147  0.11150632 -0.01132915]), Klaster: 0, Centroid: [ 0.02343901 -0.19004975  0.04625305 -0.01722975], Jarak kuadrat: 0.007, Inertia sementara: 7.729
# Titik data 85 (Fitur: [-0.38205585 -0.10286424  0.0251417  -0.02903094]), Klaster: 0, Centroid: [ 0.02343901 -0.19004975  0.04625305 -0.01722975], Jarak kuadrat: 0.173, Inertia sementara: 7.901
# Titik data 86 (Fitur: [ 0.03984632  0.07297207  0.0251417  -0.01132915]), Klaster: 0, Centroid: [ 0.02343901 -0.19004975  0.04625305 -0.01722975], Jarak kuadrat: 0.070, Inertia sementara: 7.971
# Titik data 87 (Fitur: [ 0.53206551 -0.05890516  0.05392991 -0.02903094]), Klaster: 3, Centroid: [ 0.73267586 -0.06795556  0.18305349  0.05114777], Jarak kuadrat: 0.063, Inertia sementara: 8.035
# Titik data 88 (Fitur: [ 0.2507974  -0.41057779  0.0107476  -0.06443453]), Klaster: 0, Centroid: [ 0.02343901 -0.19004975  0.04625305 -0.01722975], Jarak kuadrat: 0.104, Inertia sementara: 8.138
# Titik data 89 (Fitur: [-0.2414218  -0.10286424 -0.03243471 -0.06443453]), Klaster: 0, Centroid: [ 0.02343901 -0.19004975  0.04625305 -0.01722975], Jarak kuadrat: 0.086, Inertia sementara: 8.225
# Titik data 90 (Fitur: [-0.31173882 -0.32265963 -0.04682882 -0.06443453]), Klaster: 0, Centroid: [ 0.02343901 -0.19004975  0.04625305 -0.01722975], Jarak kuadrat: 0.141, Inertia sementara: 8.365
# Titik data 91 (Fitur: [-0.31173882 -0.27870055  0.0107476  -0.08213633]), Klaster: 0, Centroid: [ 0.02343901 -0.19004975  0.04625305 -0.01722975], Jarak kuadrat: 0.126, Inertia sementara: 8.491
# Titik data 92 (Fitur: [ 0.11016334 -0.10286424  0.03953581 -0.04673274]), Klaster: 0, Centroid: [ 0.02343901 -0.19004975  0.04625305 -0.01722975], Jarak kuadrat: 0.016, Inertia sementara: 8.507
# Titik data 93 (Fitur: [-0.10078774 -0.27870055 -0.04682882 -0.08213633]), Klaster: 0, Centroid: [ 0.02343901 -0.19004975  0.04625305 -0.01722975], Jarak kuadrat: 0.036, Inertia sementara: 8.543
# Titik data 94 (Fitur: [-0.66332396 -0.41057779 -0.14758755 -0.11753991]), Klaster: 2, Centroid: [-0.65948849  0.03141076 -0.37841663 -0.2327625 ], Jarak kuadrat: 0.262, Inertia sementara: 8.805
# Titik data 95 (Fitur: [-0.2414218  -0.23474147 -0.01804061 -0.06443453]), Klaster: 0, Centroid: [ 0.02343901 -0.19004975  0.04625305 -0.01722975], Jarak kuadrat: 0.079, Inertia sementara: 8.884
# Titik data 96 (Fitur: [-0.17110477 -0.10286424 -0.01804061 -0.08213633]), Klaster: 0, Centroid: [ 0.02343901 -0.19004975  0.04625305 -0.01722975], Jarak kuadrat: 0.054, Inertia sementara: 8.937
# Titik data 97 (Fitur: [-0.17110477 -0.14682332 -0.01804061 -0.06443453]), Klaster: 0, Centroid: [ 0.02343901 -0.19004975  0.04625305 -0.01722975], Jarak kuadrat: 0.046, Inertia sementara: 8.984
# Titik data 98 (Fitur: [ 0.18048037 -0.14682332 -0.00364651 -0.06443453]), Klaster: 0, Centroid: [ 0.02343901 -0.19004975  0.04625305 -0.01722975], Jarak kuadrat: 0.031, Inertia sementara: 9.015
# Titik data 99 (Fitur: [-0.59300694 -0.32265963 -0.19076986 -0.09983812]), Klaster: 2, Centroid: [-0.65948849  0.03141076 -0.37841663 -0.2327625 ], Jarak kuadrat: 0.183, Inertia sementara: 9.197
# Titik data 100 (Fitur: [-0.17110477 -0.1907824  -0.03243471 -0.06443453]), Klaster: 0, Centroid: [ 0.02343901 -0.19004975  0.04625305 -0.01722975], Jarak kuadrat: 0.046, Inertia sementara: 9.244
# Titik data 101 (Fitur: [0.2507974  0.02901299 0.24105326 0.147987  ]), Klaster: 0, Centroid: [ 0.02343901 -0.19004975  0.04625305 -0.01722975], Jarak kuadrat: 0.165, Inertia sementara: 9.409
# Titik data 102 (Fitur: [-0.10078774 -0.23474147  0.11150632  0.04177623]), Klaster: 0, Centroid: [ 0.02343901 -0.19004975  0.04625305 -0.01722975], Jarak kuadrat: 0.025, Inertia sementara: 9.434
# Titik data 103 (Fitur: [ 0.81333362 -0.10286424  0.22665916  0.07717982]), Klaster: 3, Centroid: [ 0.73267586 -0.06795556  0.18305349  0.05114777], Jarak kuadrat: 0.010, Inertia sementara: 9.444
# Titik data 104 (Fitur: [ 0.2507974  -0.14682332  0.18347684  0.02407444]), Klaster: 0, Centroid: [ 0.02343901 -0.19004975  0.04625305 -0.01722975], Jarak kuadrat: 0.074, Inertia sementara: 9.518
# Titik data 105 (Fitur: [ 0.39143146 -0.10286424  0.21226505  0.09488162]), Klaster: 3, Centroid: [ 0.73267586 -0.06795556  0.18305349  0.05114777], Jarak kuadrat: 0.120, Inertia sementara: 9.639
# Titik data 106 (Fitur: [ 1.16491876 -0.10286424  0.32741788  0.07717982]), Klaster: 3, Centroid: [ 0.73267586 -0.06795556  0.18305349  0.05114777], Jarak kuadrat: 0.210, Inertia sementara: 9.848
# Titik data 107 (Fitur: [-0.73364099 -0.32265963  0.0251417   0.00637265]), Klaster: 2, Centroid: [-0.65948849  0.03141076 -0.37841663 -0.2327625 ], Jarak kuadrat: 0.351, Inertia sementara: 10.199
# Titik data 108 (Fitur: [ 0.95396768 -0.14682332  0.28423557  0.02407444]), Klaster: 3, Centroid: [ 0.73267586 -0.06795556  0.18305349  0.05114777], Jarak kuadrat: 0.066, Inertia sementara: 10.265
# Titik data 109 (Fitur: [ 0.53206551 -0.32265963  0.21226505  0.02407444]), Klaster: 3, Centroid: [ 0.73267586 -0.06795556  0.18305349  0.05114777], Jarak kuadrat: 0.107, Inertia sementara: 10.372
# Titik data 110 (Fitur: [0.88365065 0.16089022 0.25544736 0.147987  ]), Klaster: 3, Centroid: [ 0.73267586 -0.06795556  0.18305349  0.05114777], Jarak kuadrat: 0.090, Inertia sementara: 10.462
# Titik data 111 (Fitur: [ 0.39143146 -0.01494609  0.11150632  0.05947803]), Klaster: 3, Centroid: [ 0.73267586 -0.06795556  0.18305349  0.05114777], Jarak kuadrat: 0.124, Inertia sementara: 10.586
# Titik data 112 (Fitur: [ 0.32111443 -0.23474147  0.14029453  0.04177623]), Klaster: 0, Centroid: [ 0.02343901 -0.19004975  0.04625305 -0.01722975], Jarak kuadrat: 0.103, Inertia sementara: 10.689
# Titik data 113 (Fitur: [ 0.60238254 -0.10286424  0.16908274  0.07717982]), Klaster: 3, Centroid: [ 0.73267586 -0.06795556  0.18305349  0.05114777], Jarak kuadrat: 0.019, Inertia sementara: 10.708
# Titik data 114 (Fitur: [-0.17110477 -0.32265963  0.09711222  0.05947803]), Klaster: 0, Centroid: [ 0.02343901 -0.19004975  0.04625305 -0.01722975], Jarak kuadrat: 0.064, Inertia sementara: 10.772
# Titik data 115 (Fitur: [-0.10078774 -0.1907824   0.11150632  0.13028521]), Klaster: 0, Centroid: [ 0.02343901 -0.19004975  0.04625305 -0.01722975], Jarak kuadrat: 0.041, Inertia sementara: 10.814
# Titik data 116 (Fitur: [ 0.32111443 -0.01494609  0.14029453  0.11258341]), Klaster: 0, Centroid: [ 0.02343901 -0.19004975  0.04625305 -0.01722975], Jarak kuadrat: 0.145, Inertia sementara: 10.959
# Titik data 117 (Fitur: [ 0.39143146 -0.10286424  0.16908274  0.02407444]), Klaster: 3, Centroid: [ 0.73267586 -0.06795556  0.18305349  0.05114777], Jarak kuadrat: 0.119, Inertia sementara: 11.077
# Titik data 118 (Fitur: [1.23523579 0.24880838 0.34181199 0.09488162]), Klaster: 3, Centroid: [ 0.73267586 -0.06795556  0.18305349  0.05114777], Jarak kuadrat: 0.380, Inertia sementara: 11.457
# Titik data 119 (Fitur: [ 1.23523579 -0.27870055  0.37060019  0.11258341]), Klaster: 3, Centroid: [ 0.73267586 -0.06795556  0.18305349  0.05114777], Jarak kuadrat: 0.336, Inertia sementara: 11.793
# Titik data 120 (Fitur: [ 0.03984632 -0.45453686  0.09711222 -0.02903094]), Klaster: 0, Centroid: [ 0.02343901 -0.19004975  0.04625305 -0.01722975], Jarak kuadrat: 0.073, Inertia sementara: 11.866
# Titik data 121 (Fitur: [ 0.67269957 -0.01494609  0.19787095  0.11258341]), Klaster: 3, Centroid: [ 0.73267586 -0.06795556  0.18305349  0.05114777], Jarak kuadrat: 0.010, Inertia sementara: 11.876
# Titik data 122 (Fitur: [-0.2414218  -0.1907824   0.08271812  0.05947803]), Klaster: 0, Centroid: [ 0.02343901 -0.19004975  0.04625305 -0.01722975], Jarak kuadrat: 0.077, Inertia sementara: 11.954
# Titik data 123 (Fitur: [ 1.23523579 -0.1907824   0.34181199  0.05947803]), Klaster: 3, Centroid: [ 0.73267586 -0.06795556  0.18305349  0.05114777], Jarak kuadrat: 0.293, Inertia sementara: 12.247
# Titik data 124 (Fitur: [ 0.2507974  -0.23474147  0.08271812  0.02407444]), Klaster: 0, Centroid: [ 0.02343901 -0.19004975  0.04625305 -0.01722975], Jarak kuadrat: 0.057, Inertia sementara: 12.303
# Titik data 125 (Fitur: [0.53206551 0.02901299 0.19787095 0.07717982]), Klaster: 3, Centroid: [ 0.73267586 -0.06795556  0.18305349  0.05114777], Jarak kuadrat: 0.051, Inertia sementara: 12.354
# Titik data 126 (Fitur: [ 0.88365065 -0.01494609  0.24105326  0.02407444]), Klaster: 3, Centroid: [ 0.73267586 -0.06795556  0.18305349  0.05114777], Jarak kuadrat: 0.030, Inertia sementara: 12.384
# Titik data 127 (Fitur: [ 0.18048037 -0.1907824   0.06832401  0.02407444]), Klaster: 0, Centroid: [ 0.02343901 -0.19004975  0.04625305 -0.01722975], Jarak kuadrat: 0.027, Inertia sementara: 12.411
# Titik data 128 (Fitur: [ 0.11016334 -0.10286424  0.08271812  0.02407444]), Klaster: 0, Centroid: [ 0.02343901 -0.19004975  0.04625305 -0.01722975], Jarak kuadrat: 0.018, Inertia sementara: 12.429
# Titik data 129 (Fitur: [ 0.32111443 -0.1907824   0.18347684  0.07717982]), Klaster: 0, Centroid: [ 0.02343901 -0.19004975  0.04625305 -0.01722975], Jarak kuadrat: 0.116, Inertia sementara: 12.545
# Titik data 130 (Fitur: [ 0.88365065 -0.10286424  0.21226505 -0.01132915]), Klaster: 3, Centroid: [ 0.73267586 -0.06795556  0.18305349  0.05114777], Jarak kuadrat: 0.029, Inertia sementara: 12.574
# Titik data 131 (Fitur: [ 1.02428471 -0.1907824   0.25544736  0.04177623]), Klaster: 3, Centroid: [ 0.73267586 -0.06795556  0.18305349  0.05114777], Jarak kuadrat: 0.105, Inertia sementara: 12.679
# Titik data 132 (Fitur: [1.37586985 0.24880838 0.29862968 0.05947803]), Klaster: 3, Centroid: [ 0.73267586 -0.06795556  0.18305349  0.05114777], Jarak kuadrat: 0.527, Inertia sementara: 13.207
# Titik data 133 (Fitur: [ 0.32111443 -0.1907824   0.18347684  0.09488162]), Klaster: 0, Centroid: [ 0.02343901 -0.19004975  0.04625305 -0.01722975], Jarak kuadrat: 0.120, Inertia sementara: 13.327
# Titik data 134 (Fitur: [ 0.2507974  -0.1907824   0.11150632 -0.02903094]), Klaster: 0, Centroid: [ 0.02343901 -0.19004975  0.04625305 -0.01722975], Jarak kuadrat: 0.056, Inertia sementara: 13.383
# Titik data 135 (Fitur: [ 0.11016334 -0.27870055  0.18347684 -0.04673274]), Klaster: 0, Centroid: [ 0.02343901 -0.19004975  0.04625305 -0.01722975], Jarak kuadrat: 0.035, Inertia sementara: 13.418
# Titik data 136 (Fitur: [ 1.23523579 -0.10286424  0.25544736  0.11258341]), Klaster: 3, Centroid: [ 0.73267586 -0.06795556  0.18305349  0.05114777], Jarak kuadrat: 0.263, Inertia sementara: 13.681
# Titik data 137 (Fitur: [0.2507974  0.07297207 0.18347684 0.13028521]), Klaster: 0, Centroid: [ 0.02343901 -0.19004975  0.04625305 -0.01722975], Jarak kuadrat: 0.161, Inertia sementara: 13.842
# Titik data 138 (Fitur: [ 0.32111443 -0.05890516  0.16908274  0.02407444]), Klaster: 0, Centroid: [ 0.02343901 -0.19004975  0.04625305 -0.01722975], Jarak kuadrat: 0.123, Inertia sementara: 13.965
# Titik data 139 (Fitur: [ 0.03984632 -0.10286424  0.06832401  0.02407444]), Klaster: 0, Centroid: [ 0.02343901 -0.19004975  0.04625305 -0.01722975], Jarak kuadrat: 0.010, Inertia sementara: 13.975
# Titik data 140 (Fitur: [ 0.67269957 -0.05890516  0.15468864  0.07717982]), Klaster: 3, Centroid: [ 0.73267586 -0.06795556  0.18305349  0.05114777], Jarak kuadrat: 0.005, Inertia sementara: 13.980
# Titik data 141 (Fitur: [ 0.53206551 -0.05890516  0.18347684  0.13028521]), Klaster: 3, Centroid: [ 0.73267586 -0.06795556  0.18305349  0.05114777], Jarak kuadrat: 0.047, Inertia sementara: 14.027
# Titik data 142 (Fitur: [ 0.67269957 -0.05890516  0.11150632  0.11258341]), Klaster: 3, Centroid: [ 0.73267586 -0.06795556  0.18305349  0.05114777], Jarak kuadrat: 0.013, Inertia sementara: 14.039
# Titik data 143 (Fitur: [-0.10078774 -0.23474147  0.11150632  0.04177623]), Klaster: 0, Centroid: [ 0.02343901 -0.19004975  0.04625305 -0.01722975], Jarak kuadrat: 0.025, Inertia sementara: 14.064
# Titik data 144 (Fitur: [ 0.60238254 -0.01494609  0.22665916  0.11258341]), Klaster: 3, Centroid: [ 0.73267586 -0.06795556  0.18305349  0.05114777], Jarak kuadrat: 0.025, Inertia sementara: 14.090
# Titik data 145 (Fitur: [0.53206551 0.02901299 0.19787095 0.147987  ]), Klaster: 3, Centroid: [ 0.73267586 -0.06795556  0.18305349  0.05114777], Jarak kuadrat: 0.059, Inertia sementara: 14.149
# Titik data 146 (Fitur: [ 0.53206551 -0.10286424  0.12590043  0.11258341]), Klaster: 3, Centroid: [ 0.73267586 -0.06795556  0.18305349  0.05114777], Jarak kuadrat: 0.049, Inertia sementara: 14.198
# Titik data 147 (Fitur: [ 0.2507974  -0.32265963  0.09711222  0.04177623]), Klaster: 0, Centroid: [ 0.02343901 -0.19004975  0.04625305 -0.01722975], Jarak kuadrat: 0.075, Inertia sementara: 14.273
# Titik data 148 (Fitur: [ 0.39143146 -0.10286424  0.12590043  0.05947803]), Klaster: 3, Centroid: [ 0.73267586 -0.06795556  0.18305349  0.05114777], Jarak kuadrat: 0.121, Inertia sementara: 14.394
# Titik data 149 (Fitur: [0.18048037 0.07297207 0.15468864 0.11258341]), Klaster: 0, Centroid: [ 0.02343901 -0.19004975  0.04625305 -0.01722975], Jarak kuadrat: 0.122, Inertia sementara: 14.516
# Titik data 150 (Fitur: [-0.03047071 -0.10286424  0.11150632  0.02407444]), Klaster: 0, Centroid: [ 0.02343901 -0.19004975  0.04625305 -0.01722975], Jarak kuadrat: 0.016, Inertia sementara: 14.533
#
# Total Inertia Manual: 14.533
# Inertia dari sklearn: 14.533
# ==================================================

# %% [markdown]
# ## **Model Plotting Diagram Elbow Method**

# %%
# 1. Siapkan fitur (X) dan label (y)
feature_names = ['sepal length', 'sepal width', 'petal length', 'petal width']
X = df_merged[feature_names].values
y = df_merged['class'].astype('category').cat.codes.values  # label dikodekan ke angka

# 2. Standarisasi data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 3. Hitung inertia untuk berbagai nilai k
inertias = []
K_range = range(1, 11)

for k in K_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X_scaled)
    inertias.append(kmeans.inertia_)

# 4. Plot Elbow Diagram
plt.figure(figsize=(9, 6))
plt.plot(K_range, inertias, 'bo-', markersize=8, label='Inertia')
plt.title("Metode Elbow - Menentukan Jumlah Klaster Optimal")
plt.xlabel("Jumlah Klaster (k)")
plt.ylabel("Inertia")
plt.xticks(K_range)
plt.grid(True)

# Tambahkan label inertia di tiap titik
for i, inertia in enumerate(inertias):
    plt.text(K_range[i], inertias[i] + 1, f"{inertia:.2f}", ha='center', fontsize=9)

plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Menghitung Silhouette Score untuk Jumlah Cluster 2,3 dan 4**

# %%
# 1. Siapkan fitur (X) dan label (y)
feature_names = ['sepal length', 'sepal width', 'petal length', 'petal width']
X = df_merged[feature_names].values
y = df_merged['class'].astype('category').cat.codes.values  # label dikodekan ke angka

# 2. Standarisasi data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 3. Fungsi untuk melakukan K-Means dan menghitung Silhouette Score
def perform_kmeans_with_silhouette(X_scaled, k):
    kmeans = KMeans(n_clusters=k, random_state=42)
    labels = kmeans.fit_predict(X_scaled)

    # Menghitung Silhouette Score
    silhouette_avg = silhouette_score(X_scaled, labels)

    # Centroid dari masing-masing klaster
    centroids = kmeans.cluster_centers_

    # Output hasil untuk klaster k
    print(f"\n=== Hasil K-Means dengan {k} Klaster ===")
    print(f"Centroids:\n{centroids}")
    print(f"Silhouette Score untuk {k} klaster: {silhouette_avg:.3f}")

    return silhouette_avg

# 4. Melakukan clustering dan menghitung Silhouette Score untuk k=2, 3, dan 4
silhouette_scores = []
k_values = [2, 3, 4]

for k in k_values:
    score = perform_kmeans_with_silhouette(X_scaled, k)
    silhouette_scores.append(score)

# 5. Menentukan k dengan Silhouette Score terbaik
best_k = k_values[np.argmax(silhouette_scores)]
best_score = max(silhouette_scores)
print(f"\n>>> Jumlah cluster terbaik dengan dengan Silhouette Score mendekati 1 adalah k = {best_k} (dengan score = {best_score:.3f})")

# 6. Plot Silhouette Scores
plt.figure(figsize=(8, 5))
plt.plot(k_values, silhouette_scores, 'bo-', markersize=8)
plt.title("Silhouette Score untuk Jumlah Klaster yang Berbeda")
plt.xlabel("Jumlah Klaster (k)")
plt.ylabel("Silhouette Score")
plt.xticks(k_values)
plt.grid(True)
plt.show()
# Out:
# === Hasil K-Means dengan 2 Klaster ===
# Centroids:
# [[-0.06680904 -0.08044216 -0.07928801 -0.08118589]
#  [ 9.95454726 11.98588211 11.81391278 12.09669818]]
# Silhouette Score untuk 2 klaster: 0.958
#
# === Hasil K-Means dengan 3 Klaster ===
# Centroids:
# [[ 0.3969107  -0.12798371  0.12328332  0.02361465]
#  [ 9.95454726 11.98588211 11.81391278 12.09669818]
#  [-0.56273155 -0.02959911 -0.29592678 -0.19326426]]
# Silhouette Score untuk 3 klaster: 0.514
#
# === Hasil K-Means dengan 4 Klaster ===
# Centroids:
# [[ 0.02343901 -0.19004975  0.04625305 -0.01722975]
#  [ 9.95454726 11.98588211 11.81391278 12.09669818]
#  [-0.65948849  0.03141076 -0.37841663 -0.2327625 ]
#  [ 0.73267586 -0.06795556  0.18305349  0.05114777]]
# Silhouette Score untuk 4 klaster: 0.471
#
# >>> Jumlah cluster terbaik dengan dengan Silhouette Score mendekati 1 adalah k = 2 (dengan score = 0.958)
